# %% [markdown]
# <a href="https://colab.research.google.com/github/lucascogrossi/CUDA-Parallel-Gaussian-Elimination/blob/main/maxheap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalho Avaliativo 2
# ## Algoritmos E Estruturas De Dados II - 2024
#
# Aluno: Lucas Machado Cogrossi

# %% [markdown]
# # Max-heap
#
# Max-heap (ou árvore hierárquica) é uma árvore binária quase completa em que cada pai é maior ou igual que qualquer de seus filho [[1]](https://www.ime.usp.br/~pf/analise_de_algoritmos/aulas/heap.html).

# %% [markdown]
# ![image.psd(1).png](data:image/png;base64,...)
